# %% [markdown]
# # Week 1: Visualizing a Decision Tree - Machine Learning Recipes #2

# %% [markdown]
# This is a guide for the Machine Learning Recipes with Josh Gordon available on [YouTube](https://www.youtube.com/playlist?list=PLOU2XLYxmsIIuiBfYad6rFYQU_jL2ryal)
#
# In the previous notebook I realized that I went too far with the exercise. I am going to stick with the examples given in the video but I will keep put in some pandas code for better representation of the data. Today we are going to show the code for:
#
# 1. importing the iris data
# 2. train a classifier
# 3. predict label for new flower
# 4. visualize the tree
#
# ## Import Iris Data

# %%
from sklearn.datasets import load_iris
from sklearn import tree
iris = load_iris()

# %%
test_idx = [0, 50,100]

# training data
train_target = np.delete(iris.target, test_idx) # this will return the iris.target exempt of element at index 0, 50 and 100
train_data= np.delete(iris.data, test_idx, axis = 0)

# testing data
test_target = iris.target[test_idx]
test_data = iris.data[test_idx]
print test_data
print test_target
# Out:
# [[ 5.1  3.5  1.4  0.2]
#  [ 7.   3.2  4.7  1.4]
#  [ 6.3  3.3  6.   2.5]]
# [0 1 2]

# %% [markdown]
# ## Train the classifier

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(train_data, train_target)

# %% [markdown]
# ## Predict labels for new flowers

# %%
print test_target
print clf.predict(test_data)
# Out:
# [0 1 2]
# [0 1 2]

# %% [markdown]
# ## Visualize the tree

# %%
from IPython.display import Image 
from sklearn.externals.six import StringIO
import pydot
dot_data = StringIO()  
tree.export_graphviz(clf, out_file=dot_data,  
                         feature_names=iris.feature_names,  
                         class_names=iris.target_names,  
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# I run the code above and got an error
# ```python
# InvocationException: GraphViz's executables not found
# ```
# in order to fix this issue, you have to install the `GraphViz` using the following cell without the *#*

# %%
#!sudo apt-get install graphviz
#!sudo pip install GraphViz

# %%
from sklearn.cross_validation import train_test_split
train_data, test_data, train_target, test_target = train_test_split(iris.data, iris.target, test_size=0.33, random_state=60)

# %% [markdown]
# ## Homework 1
# Find the preduction accuracy of the decision tree using the Iris data above

# %% [markdown]
# ## Reading
# 1. Read chapter 2 of [ESL](http://statweb.stanford.edu/~tibs/ElemStatLearn/)
# 2. Take a look at this [ressource](http://blog.kaggle.com/2015/04/22/scikit-learn-video-3-machine-learning-first-steps-with-the-iris-dataset/)
